# %%
import pandas as pd

df = pd.read_csv('C:\Volume_D\Programming\Blimp_git\data.csv', header=None)

print(df.to_string())
# Out:
#      0                     1                     2                     3
# 0  NaN                     x                     y                     z
# 1  0.0    161.32315185979036   -28.458939212440626    104.46162611459029
# 2  1.0    7.4547949377341105  -0.08715810297118834  0.030149695978930587
# 3  2.0  -0.08715810297118809     7.089354991055115   0.06028799284595603
# 4  3.0  0.030149695978930722  0.060287992845956435     7.591540778547613

# %%
pippo = df[0][0]
print(pippo)
# Out:
# -23.0

# %%
import numpy as np
from matplotlib import pyplot as plt


data = np.loadtxt('C:\Volume_D\Programming\Blimp_git\data_for_calibration.txt',delimiter=',') #input


plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[:,0], data[:,1], data[:,2], marker='o', color='r')
plt.show()

# %%
from scipy.linalg import sqrtm

a = np.array([[1.0, 3.0], [1.0, 4.0]])

r = sqrtm(a)

r
# Out:
# array([[0.75592895, 1.13389342],
#        [0.37796447, 1.88982237]])

# %%
from numpy import sqrt

a = np.array([[1.0, 3.0], [1.0, 4.0]])

r = sqrt(a)

r
# Out:
# array([[1.        , 1.73205081],
#        [1.        , 2.        ]])

# %%
# Prova per salvare cose in un dataframe 
pippo = [ 0, 1, 2, 3, 4, 5]
sum(pippo[-3 :])/3
# Out:
# 4.0

# %%
df = pd.read_csv('C:\Volume_D\Programming\Blimp_git\data.csv')
print(df)
b = np.array([df.iloc[0,1], df.iloc[0,2], df.iloc[0,3]])
A_1 = np.array([[df.iloc[1,1], df.iloc[1,2], df.iloc[1,3]],
                [df.iloc[2,1], df.iloc[2,2], df.iloc[2,3]],
                [df.iloc[3,1], df.iloc[3,2], df.iloc[3,3]]])
A_1
b[0]
# Out:
#    Unnamed: 0         x         y          z
# 0           0  7.343373  8.061443 -10.827945
# 1           1  5.794242  0.344218  -1.324104
# 2           2  0.344218  6.406482   0.830821
# 3           3 -1.324104  0.830821   6.402318
# 7.343372631279319
