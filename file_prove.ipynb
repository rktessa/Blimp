# %%
import pandas as pd

df = pd.read_csv('C:\Volume_D\Programming\Blimp_git\data.csv', header=None)

print(df.to_string())
# Out:
#           0         1          2
# 0 -23.00000  45.00000  1000.0000
# 1       NaN       NaN        NaN
# 2   1.04300   0.00400     0.3434
# 3   0.34320   1.03490     0.0569
# 4   0.00564   0.00454     1.0453

# %%
pippo = df[0][0]
print(pippo)
# Out:
# -23.0

# %%
import numpy as np
from matplotlib import pyplot as plt


data = np.loadtxt('C:\Volume_D\Programming\Blimp_git\data_for_calibration2.txt',delimiter=',') #input


plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[:,0], data[:,1], data[:,2], marker='o', color='r')
plt.show()

# %%
from scipy.linalg import sqrtm

a = np.array([[1.0, 3.0], [1.0, 4.0]])

r = sqrtm(a)

r
# Out:
# array([[0.75592895, 1.13389342],
#        [0.37796447, 1.88982237]])

# %%
from numpy import sqrt

a = np.array([[1.0, 3.0], [1.0, 4.0]])

r = sqrt(a)

r
# Out:
# array([[1.        , 1.73205081],
#        [1.        , 2.        ]])

# %%
# Prova per salvare cose in un dataframe 
pippo = np.array([0, 0, 1])
papa =  np.array([2, 3, 4])
pluto= pd.DataFrame(papa)
pluto
# Out:
#    0
# 0  2
# 1  3
# 2  4

# %%
df = pd.read_csv('C:\Volume_D\Programming\Blimp_git\data.csv')
print(df)
b = np.array([df.iloc[0,1], df.iloc[0,2], df.iloc[0,3]])
A_1 = np.array([[df.iloc[1,1], df.iloc[1,2], df.iloc[1,3]],
                [df.iloc[2,1], df.iloc[2,2], df.iloc[2,3]],
                [df.iloc[3,1], df.iloc[3,2], df.iloc[3,3]]])
A_1
b[0]
# Out:
#    Unnamed: 0         x         y          z
# 0           0  7.343373  8.061443 -10.827945
# 1           1  5.794242  0.344218  -1.324104
# 2           2  0.344218  6.406482   0.830821
# 3           3 -1.324104  0.830821   6.402318
# 7.343372631279319
